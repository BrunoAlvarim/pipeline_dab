# %%
from func.config import get_spark

spark = get_spark()

# %%
spark.read.table("demo_dab.silver.itens").show()
# Out:
# +-------+---------+--------------------+-----------+
# |item_id|nome_item|          data_carga|data_update|
# +-------+---------+--------------------+-----------+
# |      3|  MONITOR|2026-07-02 13:38:...|       NULL|
# |      7|  HEADSET|2026-07-02 13:37:...|       NULL|
# |      8|     MESA|2026-07-02 13:37:...|       NULL|
# |      9|  HEADSET|2026-07-02 13:37:...|       NULL|
# +-------+---------+--------------------+-----------+
